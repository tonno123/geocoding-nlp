# %% [markdown]
# Onderstaande plots zijn op basis van een geannoteerde dataset van 80 artikelen.

# %% [markdown]
# ### Hoeveelheid genoemde toponiemen per artikel

# %%
import annotated_stats as stats

stats.annotatedToponymStats()

# %% [markdown]
# ### Hoeveelheid daadwerkelijk verschillende locaties per artikel

# %%
stats.annotatedLocationStats()
